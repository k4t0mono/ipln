# %%
import requests
import re
import os
import justext
import pickle
from bs4 import BeautifulSoup
from pprint import pprint

# %% [markdown]
# ## Base Crawler

# %%
class BaseCrawler:
    
    def __init__(self, base_url, domain, file_prefix, savepoint=5):
        self.base_url = base_url
        self.corpus_path = '../data/corpora/{}'.format(domain)
        self.file_prefix = file_prefix
        self.links_todo = []
        self.links_done = []
        self.savepoint = savepoint
        self.pickle_dir = '.{}_links.pickle'.format(file_prefix)
        
        if os.path.isfile(self.pickle_dir):
            (self.links_done, self.links_todo) = pickle.load(open(self.pickle_dir, 'rb'))
        
        if not os.path.exists(self.corpus_path):
            os.makedirs(self.corpus_path)
            
    def save_pickle(self):
        pickle.dump((self.links_done, self.links_todo), open(self.pickle_dir, 'wb'))
        print('pickle saved')
    
    def run(self):
        if len(self.links_todo) < 1:
            self.get_post_list(1)
            self.save_pickle()
        
        l = [ x for x in self.links_todo if x not in self.links_done ]
        
        for i in range(len(l)):
            url = l[i]
            self.get_article(url)
            self.links_done.append(url)
            
            if (i+1) % self.savepoint == 0:
                self.save_pickle()
    
    def get_post_list(self, pg):
        raise NotImplementedError
    
    def get_article(self, url):
        raise NotImplementedError

# %% [markdown]
# ## Crawler para o blog da Penumbra livros

# %%
class PenumbraCrawler(BaseCrawler):

    def get_post_list(self, pg):
        print('Getting page {:02d}'.format(pg), end='\t\t')
        url = '{}/page/{}'.format(self.base_url, pg)
        res = requests.get(url)

        soup = BeautifulSoup(res.text, 'html.parser')
        articles = soup.findAll('article', { 'class': 'post' })
        
        for article in articles:
            self.links_todo.append(article.find('a').get('href'))
        
        print('Got {} articles links'.format(len(articles)))
        
        span = soup.find('span', { 'class': 'nav-previous' })
        if span == None:
            print('Got {} articles links in total'.format(len(self.links)))
            return
        
        next_pg = span.find('a').get('href').split('/')[-2]
        self.get_post_list(int(next_pg))
    
    def get_article(self, url):
        print('getting page {}'.format(url))
        res = requests.get(url)
        
        l = url.split('/')
        post_name = l[-1] if l[-1] != '' else l[-2]
        post_name = post_name.split('.html')[0].replace("-", "_")
        fl_name = '{}__{}_{}__{}'.format(self.file_prefix, l[3], l[4], post_name)

        paragraphs = justext.justext(res.text, justext.get_stoplist("Portuguese"))
        
        with open("{}/{}.txt".format(self.corpus_path, fl_name), "w") as fl:
            for p in paragraphs:
                if not p.is_boilerplate:
                    fl.write(p.text + '\n')

# %%
crawler = PenumbraCrawler('http://www.penumbralivros.com.br/home/blog/', 'ocultismo', 'penumbralivros')
crawler.run()

# %% [markdown]
# ## Crawler para o blog do Deldebbio

# %%
class DeldebbioCrawler(BaseCrawler):
    
    def get_post_list(self, pg):
        print('Getting page {:02d}'.format(pg), end='\t\t')
        
        url = '{}/page/{}'.format(self.base_url, pg)
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')
        
        articles = soup.find_all('div', { 'class': 'post' })
        for article in articles:
            self.links_todo.append(article.find('a').get('href'))
            
        print('Got {} articles links'.format(len(articles)))
        
        span = soup.find('a', { 'class': 'nextpostslink' })
        if span == None:
            print('Got {} articles links in total'.format(len(self.links_todo)))
            return
        
        next_pg = span.get('href').split('/')[-2]
        self.get_post_list(int(next_pg))
    
    def get_article(self, url):
        print('getting page {}'.format(url))
        res = requests.get(url)
        
        l = url.split('/')
        post_name = l[-1] if l[-1] != '' else l[-2]
        post_name = post_name.split('.html')[0].replace("-", "_")
        fl_name = '{}__{}'.format(self.file_prefix, post_name)

        paragraphs = justext.justext(res.text, justext.get_stoplist("Portuguese"))
        
        with open("{}/{}.txt".format(self.corpus_path, fl_name), "w") as fl:
            for p in paragraphs:
                if not p.is_boilerplate:
                    fl.write(p.text + '\n')

# %%
crawler = DeldebbioCrawler(
    'https://www.deldebbio.com.br/category/colunas/magia-do-caos/',
    'ocultismo',
    'deldebbio_caos'
)
crawler.run()

# %%
crawler = DeldebbioCrawler(
    'https://www.deldebbio.com.br/category/religioes/umbanda/',
    'ocultismo',
    'deldebbio_umbanda'
)
crawler.run()

# %% [markdown]
# ## NerdBunker - Games

# %%
class NerdBunkerCrawler(BaseCrawler):
    
    def get_post_list(self, pg):
        print('Getting page {:02d}'.format(pg), end='\t\t')
        
        url = '{}/?search=&category=games&page={}'.format(self.base_url, pg)
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')
        
        articles = soup.find_all('article', { 'class': 'entry-card' })
        for article in articles:
            self.links_todo.append(article.find('h2').find('a').get('href'))
            
        print('Got {} articles links'.format(len(articles)))
        
        if len(self.links_todo) >= 500:
            print('Got {} articles links in total'.format(len(self.links_todo)))
            return
        
        next_pg = pg + 1
        self.get_post_list(int(next_pg))
    
    def get_article(self, url):
        print('getting page {}'.format(url))
        res = requests.get(url)
        
        l = url.split('/')
        post_name = l[-1] if l[-1] != '' else l[-2]
        post_name = post_name.split('.html')[0].replace("-", "_")
        fl_name = '{}__{}'.format(self.file_prefix, post_name)

        paragraphs = justext.justext(res.text, justext.get_stoplist("Portuguese"))
        
        with open("{}/{}.txt".format(self.corpus_path, fl_name), "w") as fl:
            for p in paragraphs:
                if not p.is_boilerplate:
                    fl.write(p.text + '\n')

# %%
crawler = NerdBunkerCrawler(
    'https://jovemnerd.com.br/nerdbunker/categoria/games/',
    'games',
    'nerdbunker'
)
crawler.run()
# Out:
# Getting page 01		Got 10 articles links
# Getting page 02		Got 10 articles links
# Getting page 03		Got 10 articles links
# Getting page 04		Got 10 articles links
# Getting page 05		Got 10 articles links
# Getting page 06		Got 10 articles links
# Getting page 07		Got 10 articles links
# Getting page 08		Got 10 articles links
# Getting page 09		Got 10 articles links
# Getting page 10		Got 10 articles links
# Getting page 11		Got 10 articles links
# Getting page 12		Got 10 articles links
# Getting page 13		Got 10 articles links
# Getting page 14		Got 10 articles links
# Getting page 15		Got 10 articles links
# Getting page 16		Got 10 articles links
# Getting page 17		Got 10 articles links
# Getting page 18		Got 10 articles links
# Getting page 19		Got 10 articles links
# Getting page 20		Got 10 articles links
# Getting page 21		Got 10 articles links
# Getting page 22		Got 10 articles links
# Getting page 23		Got 10 articles links
# Getting page 24		Got 10 articles links
# Getting page 25		Got 10 articles links
# Getting page 26		Got 10 articles links
# Getting page 27		Got 10 articles links
# Getting page 28		Got 10 articles links
# Getting page 29		Got 10 articles links
# Getting page 30		Got 10 articles links
# Getting page 31		Got 10 articles links
# Getting page 32		Got 10 articles links
# Getting page 33		Got 10 articles links
# Getting page 34		Got 10 articles links
# Getting page 35		Got 10 articles links
# Getting page 36		Got 10 articles links
# Getting page 37		Got 10 articles links
# Getting page 38		Got 10 articles links
# Getting page 39		Got 10 articles links
# Getting page 40		Got 10 articles links
# Getting page 41		Got 10 articles links
# Getting page 42		Got 10 articles links
# Getting page 43		Got 10 articles links
# Getting page 44		Got 10 articles links
# Getting page 45		Got 10 articles links
# Getting page 46		Got 10 articles links
# Getting page 47		Got 10 articles links
# Getting page 48		Got 10 articles links
# Getting page 49		Got 10 articles links
# Getting page 50		Got 10 articles links
# Got 500 articles links in total
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/sony-teve-ano-mais-lucrativo-historia-empresa/
# getting page https://jovemnerd.com.br/nerdbunker/playstation-5-nao-sera-lancado-antes-maio-2020/
# getting page https://jovemnerd.com.br/nerdbunker/proximo-jogo-titanfall-adiado-estudio-foco-apex-legends/
# getting page https://jovemnerd.com.br/nerdbunker/skin-sombra-diablo-disponivel-overwatch/
# getting page https://jovemnerd.com.br/nerdbunker/derrote-ajude-thanos-evento-crossover-fortnite-vingadores/
# pickle saved
# getting page https://jovemnerd.com.br/nerdbunker/psn-japonesa-vazado-proximos-jogos-gratuitos-ps-plus/
# getting page https://jovemnerd.com.br/nerdbunker/serie-peaky-blinders-ganhar-jogo-realidade-virtual/
# getting page https://jovemnerd.com.br/nerdbunker/franquia-alien-vai-ganhar-um-rpg-de-mesa/
# getting page https://jovemnerd.com.br/nerdbunker/persona-5-dois-novos-jogos-da-franquia-anunciados/
# getting page https://jovemnerd.com.br/nerdbunker/pensei-perdido-tudo-kojima-desligamento-konami/
# ------------------------------------------------------
# KeyboardInterrupt    Traceback (most recent call last)
# <ipython-input-7-e0fa6ce7b4f8> in <module>
#       4     'nerdbunker'
#       5 )
# ----> 6 crawler.run()
#
# <ipython-input-2-4ee605fc606d> in run(self)
#      29         for i in range(len(l)):
#      30             url = l[i]
# ---> 31             self.get_article(url)
#      32             self.links_done.append(url)
#      33
#
# <ipython-input-3-87b82eae5a26> in get_article(self, url)
#      23     def get_article(self, url):
#      24         print('getting page {}'.format(url))
# ---> 25         res = requests.get(url)
#      26
#      27         l = url.split('/')
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/site-packages/urllib3/response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# /usr/lib64/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib64/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib64/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
url = 'https://jovemnerd.com.br/nerdbunker/categoria/games/?search=&category=games&page=1'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
with open('.nerdbunker_links.pickle') as fl:
    (a, b) = pickle.load(fl)
# Out:
# ------------------------------------------------------
# UnicodeDecodeError   Traceback (most recent call last)
# <ipython-input-6-7aa30058ef3e> in <module>
#       1 with open('.nerdbunker_links.pickle') as fl:
# ----> 2     (a, b) = pickle.load(fl)
#
# ~/.local/share/virtualenvs/ipln-LePBjxLu/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
